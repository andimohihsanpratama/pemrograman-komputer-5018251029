# %% [markdown]
# <a href="https://colab.research.google.com/github/andimohihsanpratama/pemrograman-komputer-5018251029/blob/Main2/Week02/W02_Naval_Architecture_5018251029.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Assignment
# ## Engineering Unit and Electrical Calculator
# - Nama : Andi Moh. Ihsan Pratama
# - NRP : 5018251029
# - Kelas : A

# %%
# Task 1: Speed Unit Conversion
speed_kmh = float(input("Enter speed [km/h]: "))
speed_ms = speed_kmh / 3.6
print(f"Speed : {speed_ms:.2f} m/s")
# Out:
# Enter speed [km/h]: 1000
# Speed : 277.78 m/s

# %%
# Task 2: Power Unit Conversion
power_kw = float(input("Power [kW]: "))
power_w = power_kw * 1000
print(f"Power : {power_w:.2f} W")
# Out:
# Power [kW]: 1000
# Power : 1000000.00 W

# %%
# Task 3: Electrical Power and Energy Calculator
voltage = float(input("Enter Voltage [V]: "))
current = float(input("Enter Current [A]: "))
operating_time = float(input("Enter Operating Time [h]: "))

power = voltage * current
energy = power * operating_time

print("\n===== ELECTRICAL CALCULATION =====")
print(f"Voltage        = {voltage:.2f} V")
print(f"Current        = {current:.2f} A")
print(f"Power          = {power:.2f} W")
print(f"Operating Time = {operating_time:.2f} hour")
print(f"Energy         = {energy:.2f} Wh")
print("-" * 35)

# Task 4: Comparison and Logical Operators
power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power      : {is_high_power}")
print(f"High voltage    : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition   : {is_high_power or is_high_voltage}")
# Out:
# Enter Voltage [V]: 1000
# Enter Current [A]: 1000
# Enter Operating Time [h]: 1000
#
# ===== ELECTRICAL CALCULATION =====
# Voltage        = 1000.00 V
# Current        = 1000.00 A
# Power          = 1000000.00 W
# Operating Time = 1000.00 hour
# Energy         = 1000000000.00 Wh
# -----------------------------------
# High power      : True
# High voltage    : True
# Both conditions : True
# Any condition   : True

# %%
# Task 3: Electrical Power and Energy Calculator
voltage = float(input("Enter Voltage [V]: "))
current = float(input("Enter Current [A]: "))
operating_time = float(input("Enter Operating Time [h]: "))

power = voltage * current
energy = power * operating_time

print("\n===== ELECTRICAL CALCULATION =====")
print(f"Voltage        = {voltage:.2f} V")
print(f"Current        = {current:.2f} A")
print(f"Power          = {power:.2f} W")
print(f"Operating Time = {operating_time:.2f} hour")
print(f"Energy         = {energy:.2f} Wh")
print("-" * 35)

# Task 4: Comparison and Logical Operators
power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power      : {is_high_power}")
print(f"High voltage    : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition   : {is_high_power or is_high_voltage}")
# Out:
# Enter Voltage [V]: 50
# Enter Current [A]: 1.2
# Enter Operating Time [h]: 24
#
# ===== ELECTRICAL CALCULATION =====
# Voltage        = 50.00 V
# Current        = 1.20 A
# Power          = 60.00 W
# Operating Time = 24.00 hour
# Energy         = 1440.00 Wh
# -----------------------------------
# High power      : False
# High voltage    : True
# Both conditions : False
# Any condition   : True

# %%
# Task 3: Electrical Power and Energy Calculator
voltage = float(input("Enter Voltage [V]: "))
current = float(input("Enter Current [A]: "))
operating_time = float(input("Enter Operating Time [h]: "))

power = voltage * current
energy = power * operating_time

print("\n===== ELECTRICAL CALCULATION =====")
print(f"Voltage        = {voltage:.2f} V")
print(f"Current        = {current:.2f} A")
print(f"Power          = {power:.2f} W")
print(f"Operating Time = {operating_time:.2f} hour")
print(f"Energy         = {energy:.2f} Wh")
print("-" * 35)

# Task 4: Comparison and Logical Operators
power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power      : {is_high_power}")
print(f"High voltage    : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition   : {is_high_power or is_high_voltage}")
# Out:
# Enter Voltage [V]: 48
# Enter Current [A]: 10
# Enter Operating Time [h]: 24
#
# ===== ELECTRICAL CALCULATION =====
# Voltage        = 48.00 V
# Current        = 10.00 A
# Power          = 480.00 W
# Operating Time = 24.00 hour
# Energy         = 11520.00 Wh
# -----------------------------------
# High power      : True
# High voltage    : True
# Both conditions : True
# Any condition   : True

# %% [markdown]
# ## Short Reflection
#
# 1. **Apa perbedaan int dan float?**
# int adalah Tipe data bilangan bulat (contoh: 5, -10), sedangkan float adalah Tipe data bilangan desimal/pecahan (contoh: 3.6, 12.5).
#
# 2. **Mengapa hasil input() perlu dikonversi menggunakan float() untuk perhitungan numerik?**
#    Fungsi input() menghasilkan tipe data string (str). Konversi ke float() diperlukan agar nilai masukan tersebut dapat dihitung secara matematis.
#
# 3. **Apa perbedaan operator = dan == dalam Python?**
#
#    = : Operator penugasan (assign) untuk memasukkan nilai ke dalam variabel.
#
#    == : Operator perbandingan (equality) untuk mengecek apakah dua nilai bernilai sama (menghasilkan True / False).
#
# 4. **Apa fungsi operator and dan or?**
#
#    and : Menghasilkan True jika **kedua** kondisi bernilai True.
#
#    or : Menghasilkan True jika **salah satu** atau kedua kondisi bernilai True.
#
# 5. **Apa satu kesalahan yang Anda temui saat mengerjakan tugas ini, dan bagaimana Anda memperbaikinya?**
#
#     Saat pertama kali mencoba, input berupa angka masih ber-tipe string sehingga terjadi error saat perkalian, lalu diperbaiki dengan membungkus fungsi input() menggunakan float().
